# %%
# PRUEBA DE PYTHON

print('hello, Python!')
# Out:
# hello, Python!

# %% [markdown]
# prueba para poner palabras y las pueda reconocer

# %%
# Comprobar la versión de python

import sys
print(sys.version)
# Out:
# 3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]

# %% [markdown]
# comprobar la versión de python con print(sys.version)

# %%
print('Hello, python!') # Esta línea imprime un String
# print('Hola)
# Out:
# Hello, python!

# %% [markdown]
# al poner # antes de escribir el comentario no ejecutara lo que se escribio. cuando quiero poner una palabra nunca se pone el #

# %%
print("""Hello, Python!""")
# Out:
# Hello, Python!

# %%
#imprime el primere string y la segunda linea da error

print("This will be printed")
frint("This will cause an error")
print("This will NOT be printend")
# Out:
# This will be printed
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-73b87b9a3aa7> in <module>
#       2
#       3 print("This will be printed")
# ----> 4 frint("This will cause an error")
#       5 print("This will NOT be printend")
#
# NameError: name 'frint' is not defined

# %% [markdown]
# Cuando se pone una palabra que no reconoce le saldra error y no ejecutara las demás celdas.

# %%
# Escribe tu codigo deajo. No te olvides de pulsar Shif+Enter para ejecutar la celda
print("Hola, mundo!")
# Out:
# Hola, mundo!

# %%
# Escribe tu codigo deajo. No te olvides de pulsar Shif+Enter para ejecutar la celda
print("!Hola, mundo!") # Imprime el tradicional Hola mudo
# Out:
# !Hola, mundo!

# %% [markdown]
# Es importante no poner espacio en print antes despues del # no se vera cuando se ejecute

# %%
# INT

11
# Out:
# 11

# %% [markdown]
# Números enteros

# %%
# FLOAT

2.14
# Out:
# 2.14

# %% [markdown]
# Número con decimales Flotantes o Float

# %%
# Texto

"Hola, Python 101!"
# Out:
# 'Hola, Python 101!'

# %%
# Tipo de 12

type(12)
# Out:
# int

# %%
# Tipo de 2.14
type(2.14)
# Out:
# float

# %%
# Tipo "Hola mundo!"

type("Hola Mundo!")
# Out:
# str

# %%
# Escriba ru código a continuación. No olvides presionar Shif+Enter para ejecutar.
type(12.0)
# Out:
# float

# %%
#  Tipo de True

type(True)
# Out:
# bool

# %%
# Tipo de Falso

type(False)
# Out:
# bool

# %% [markdown]
# Type es para saber si es un texto, número entero o con decimales.

# %%
# Convierte una cadena en un entero de manera errónea

int('1.2')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-73e49993dc6c> in <module>
#       1 # Convierte una cadena en un entero de manera errónea
#       2
# ----> 3 int('1.2')
#
# ValueError: invalid literal for int() with base 10: '1.2'

# %%
# Convierte la cadena "1.2" en un número flotante

float('1.2')
# Out:
# 1.2

# %% [markdown]
# No se puede mezclar "1.2' tiene que ser siempre '1.2' o "1.2"

# %%
# Convierte un número entero en una cadena

str(1)
# Out:
# '1'

# %% [markdown]
# convierto un string en un número entero

# %%
# Convierte un número entero en una cadena

str(1.2)
# Out:
# '1.2'

# %%
# Valor verdadero

True
# Out:
# True

# %%
# Valor falso

False
# Out:
# False

# %% [markdown]
# tipo Booleano para poner si es verdadero o falso.

# %%
# Convierte un 1 en un booleano

bool(1)
# Out:
# True

# %%
# Convierte un 0 en un booleano

bool(0)
# Out:
# False

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda
6 / 2
# Out:
# 3.0

# %% [markdown]
# una / signifa número flotantes.

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda
6 // 2
# Out:
# 3

# %% [markdown]
# // significa número natural.

# %%
# Expresión de operación de suma.

43 + 60 + 16 + 41
# Out:
# 160

# %%
# Expresión de operación de resta.

50 - 60
# Out:
# -10

# %%
# Expresión de operación de multiplicación

5 * 5
# Out:
# 25

# %%
# Expresión de operación de división

25 / 5
# Out:
# 5.0

# %%
# Expresión de operación de división

25 / 6
# Out:
# 4.166666666666667

# %% [markdown]
# Expresiones de operaciones

# %%
# Expresión de operación de división de enteros

25 // 5
# Out:
# 5

# %%
# Expresión de operación de de enteros

25 // 6
# Out:
# 4

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda

160 / 60
# Out:
# 2.6666666666666665

# %% [markdown]
# se divide los minutos que me dieron entre los minutos que tiene una hora. y sacamos cuantas horas serian en total.

# %%
# Expresión matemáticas

30 + 2 * 60
# Out:
# 150

# %%
# expe

30 + (2 * 60)
# Out:
# 150

# %%
# Expresión matemática

(30 + 2) * 60
# Out:
# 1920

# %%
# Guarda el valor de una variable

x = 43 + 60 + 16 + 41

# %%
# Imprime el valor de la variable

x
# Out:
# 160

# %%
# Usa otra variable para almacenar el resultado de la operación entre la variable

y = x / 60
y
# Out:
# 2.6666666666666665

# %%
# Sobreescribe una variable con un nuevo valor
x = 160
x = x / 60
x
# Out:
# 2.6666666666666665

# %%
# Pone un nombre con significado a la variable
total_min = 43 + 42 + 57 # La duración total de varios álbumes en minutos
total_min
# Out:
# 142

# %%
# Pone un nimbre con significado a la variable

total_hours = total_min / 60 # La duración de varios álbumes en horas
total_hours
# Out:
# 2.3666666666666667

# %%
# Expresión comploicada

total_hours = (43 + 42 + 57) / 60 # Horas totales en una sola expresión.
total_hours
# Out:
# 2.3666666666666667

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda

x = 3 + 2 * 2 
x
# Out:
# 7

# %% [markdown]
# se multiplica 2 * 2 + 3 para que de 7

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda

y = (3 + 2) * 2
y
# Out:
# 10

# %% [markdown]
# se suma lo del parentesis (3 + 2)= 5 * 2 = 10

# %%
# Escriba tu código a continuación. No olvides presionar Shift+Enter para ejecutar la celda

z = x + y
z
# Out:
# 17

# %% [markdown]
# para sacar la z se suma x =7 + y =10 seria z= 17

# %%
# Imprimir una línea "Esto es una función print"

print("Hola" + " " + "mundo")
# Out:
# Hola mundo

# %%
#Guarda un int e imprime por pantalla
myint = 7
myint # la última línea del código imprime
# Out:
# 7

# %%
# Guarda u float e imprime por pantalla
myfloat = 7.0
myfloat
# Out:
# 7.0

# %%
#Guarda un string e imprime por pantalla
mystring = 'Hola'
mystring
# Out:
# 'Hola'

# %%
# Guarda dos números, sumalos e imprime por pantalla
one = 1
two = 2
one + two
# Out:
# 3

# %%
#Guarda estos dos strings con un espacio en el medio
hello = 'hola '
world = 'mundo'
hello + world
# Out:
# 'hola mundo'

# %% [markdown]
# se pone espacio antes o despues de la palabra

# %%
#Mira como se asignan dos valores a la vez
a, b = 3, 4
a, b
# Out:
# (3, 4)

# %%
#Guarda una lista e imprime por pantalla
mylist =[1, 2, 3]
mylist
# Out:
# [1, 2, 3]

# %%
#Guarda una lista con diferentes tipos e imprime por pantalla
mylist = [1, 'hola', True]
mylist
# Out:
# [1, 'hola', True]

# %% [markdown]
# la lista siempre se pone corchetes

# %%
#Comprueba el tipo del objeto anterior
list
# Out:
# list

# %%
#Imprime el valor de una posición solo
mylist[1]
# Out:
# 'hola'

# %%
# Guarda valores en la siguientes lista usando insert() e imprime por pantalla
mylista = []

# %%
number = 1 + 2 * 3 / 4.0
number
# Out:
# 2.5

# %% [markdown]
# primero se multiplica 2*3= 6 luego se divide / 4.0= 1.5 y se suma + 1 = 2.5

# %%
#divide 1 entre 2
1 / 2
# Out:
# 0.5

# %%
# Haz la división entera ahora de 1 entre 2 # descartar decimales
1 // 2
# Out:
# 0

# %%
#Calcula el resto de 10 entre 3 e imprime por pantalla
#pista: usa %
remainder = 10 % 3
remainder
# Out:
# 1

# %%
#eleva 7 al cuadrado y 2 al cubo
squared = 7 ** 2
cubed = 2 ** 3
print(squared)
print(cubed)
# Out:
# 49
# 8

# %%
helloworld = "hola" * 3
helloworld
# Out:
# 'holaholahola'

# %%
#concatena las dos lista
even_numbers = [2,4,6,8]
odd_numbers = [1,3,5,7]
lista = even_numbers + odd_numbers
lista.sort()
print(lista)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]
